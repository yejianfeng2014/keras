# %% [markdown]
# <a href="https://colab.research.google.com/github/yejianfeng2014/keras/blob/2019_5_15_emotion/elmo_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
import tensorflow as tf
import pandas as pd
import tensorflow_hub as hub
import os
import re
from keras import backend as K
import keras.layers as layers
from keras.models import Model, load_model
from keras.engine import Layer
import numpy as np

# Initialize session
sess = tf.Session()
K.set_session(sess)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0515 08:39:39.583506 140162050172800 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# Using TensorFlow backend.

# %%
# Load all files from a directory in a DataFrame.
def load_directory_data(directory):
  data = {}
  data["sentence"] = []
  data["sentiment"] = []
  for file_path in os.listdir(directory):
    with tf.gfile.GFile(os.path.join(directory, file_path), "r") as f:
      data["sentence"].append(f.read())
      data["sentiment"].append(re.match("\d+_(\d+)\.txt", file_path).group(1))
  return pd.DataFrame.from_dict(data)

# Merge positive and negative examples, add a polarity column and shuffle.
def load_dataset(directory):
  pos_df = load_directory_data(os.path.join(directory, "pos"))
  neg_df = load_directory_data(os.path.join(directory, "neg"))
  pos_df["polarity"] = 1
  neg_df["polarity"] = 0
  return pd.concat([pos_df, neg_df]).sample(frac=1).reset_index(drop=True)

# Download and process the dataset files.
def download_and_load_datasets(force_download=False):
  dataset = tf.keras.utils.get_file(
      fname="aclImdb.tar.gz", 
      origin="http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz", 
      extract=True)

  train_df = load_dataset(os.path.join(os.path.dirname(dataset), 
                                       "aclImdb", "train"))
  test_df = load_dataset(os.path.join(os.path.dirname(dataset), 
                                      "aclImdb", "test"))

  return train_df, test_df

# Reduce logging output.
tf.logging.set_verbosity(tf.logging.ERROR)

train_df, test_df = download_and_load_datasets()
train_df.head(100)
# Out:
#                                              sentence sentiment  polarity
# 0   it's all very simple. Jake goes to prison, and...         8         1
# 1   The first and second seasons started off shaki...        10         1
# 2   Jackie Chan's Police Story is a landmark film ...         9         1
# 3   Watching film i was in very light mood and als...         8         1
# 4   Clair Denis again revisits her theme of estran...         8         1
# 5   I don't really know where to start. The acting...         1         0
# 6   Any film that deals with bigotry in a positive...         8         1
# 7   My Super Ex-Girlfriend is an entertaining movi...         7         1
# 8   I found the film quite expressive , the way th...         8         1
# 9   Man, even Plan 9 From Outer Space is better th...         1         0
# 10  Very good martial arts film and Jet Li is the ...         7         1
# 11  Arthur Bach is decidedly unhappy in his life a...         7         1
# 12  Late, great Grade Z drive-in exploitation film...         8         1
# 13  (Some possible spoilers)<br /><br /> I'm not t...         1         0
# 14  Some kids are hiking in the mountains, and one...         2         0
# 15  Hollow Man starts as brilliant but flawed scie...         7         1
# 16  Skippy from "Family Ties" plays Eddie, a wussy...         3         0
# 17  Handsome and dashing British airline pilot Geo...         8         1
# 18  A Murder investigation goes on back stage whil...         9         1
# 19  Letters with no destination end up in another ...         8         1
# 20  Some thirty years ago, Author Numa Sadoul publ...         7         1
# 21  I cannot believe how bad this piece of garbage...         1         0
# 22  Another powerful chick flick. This time, it re...        10         1
# 23  *May contain spoilers*<br /><br />I bent over ...         3         0
# 24  The dubbing/translation in this movie is downr...         2         0
# 25  Whoever made this movie must have done it as a...         2         0
# 26  Elfriede Jelinek, not quite a household name y...         3         0
# 27  In Le Million, Rene Clair, one of the cinema's...         8         1
# 28  Outragously entertaining period piece set in t...         9         1
# 29  I recently had the pleasure of seeing The Big ...        10         1
# ..                                                ...       ...       ...
# 70  Very low-budget police procedural film about h...         3         0
# 71  Excellent story about teenagers, leaders, high...         9         1
# 72  This is one of quite a few cartoons with Bugs ...         8         1
# 73  This is an extremely long movie, which means y...         9         1
# 74  I guess this movie will only work on people wh...         7         1
# 75  I am a huge Willem Dafoe fan, and really sough...         1         0
# 76  This film is predictable; it is more predictab...         4         0
# 77  I read a small ad in some horror magazine in t...         9         1
# 78  A female vampire kills young women and paints ...         2         0
# 79  This is an excellent, heartbreaking movie. It ...        10         1
# 80  First off, anyone who thinks this sequel to Wi...         4         0
# 81  This is a lovely, spirit-restoring movie. From...        10         1
# 82  I had eagerly awaited the first screening of t...         3         0
# 83  I've seen this film several times in a variety...         4         0
# 84  Man, what a scam this turned out to be! Not be...         1         0
# 85  While the premise behind The House Where Evil ...         2         0
# 86  This a Casper the Friendly Ghost short from my...        10         1
# 87  Who is Bettie Page? I certainly didn't find ou...         3         0
# 88  This movie is basically about some girls in a ...         2         0
# 89  ***SPOILERS*** Let's start with the "good" of ...         2         0
# 90  Brian Yuzna is often frowned upon as a directo...         7         1
# 91  Lauren Bacall and Charles Boyer do not provide...         3         0
# 92  Whack!!! I got this movie because Elizabeth Ha...         1         0
# 93  I watched this on an 8 hour flight and (presum...         7         1
# 94  I saw this film in Winnipeg recently - appropr...         9         1
# 95  If I could give it a zero, I'd change my mind ...         1         0
# 96  I thoroughly enjoyed the first part of this tw...         8         1
# 97  The movie deserves 2/10. 1.5 stars for the gir...         2         0
# 98  I watched this film in a very strange way -- I...         7         1
# 99  "Maléfique" is an example of how a horror film...         8         1
#
# [100 rows x 3 columns]

# %%
# Create a custom layer that allows us to update weights (lambda layers do not have trainable parameters!)

class ElmoEmbeddingLayer(Layer):
    def __init__(self, **kwargs):
        self.dimensions = 1024
        self.trainable=True
        super(ElmoEmbeddingLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.elmo = hub.Module('https://tfhub.dev/google/elmo/2', trainable=self.trainable,
                               name="{}_module".format(self.name))

        self.trainable_weights += K.tf.trainable_variables(scope="^{}_module/.*".format(self.name))
        super(ElmoEmbeddingLayer, self).build(input_shape)

    def call(self, x, mask=None):
        result = self.elmo(K.squeeze(K.cast(x, tf.string), axis=1),
                      as_dict=True,
                      signature='default',
                      )['default']
        return result

    def compute_mask(self, inputs, mask=None):
        return K.not_equal(inputs, '--PAD--')

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.dimensions)

# %%
# Function to build model
def build_model(): 
  input_text = layers.Input(shape=(1,), dtype="string")
  embedding = ElmoEmbeddingLayer()(input_text)
  dense = layers.Dense(256, activation='relu')(embedding)
  pred = layers.Dense(1, activation='sigmoid')(dense)

  model = Model(inputs=[input_text], outputs=pred)

  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  model.summary()
  
  return model

# %%
# Create datasets (Only take up to 150 words for memory)
train_text = train_df['sentence'].tolist()
train_text = [' '.join(t.split()[0:150]) for t in train_text]
train_text = np.array(train_text, dtype=object)[:, np.newaxis]
train_label = train_df['polarity'].tolist()

test_text = test_df['sentence'].tolist()
test_text = [' '.join(t.split()[0:150]) for t in test_text]
test_text = np.array(test_text, dtype=object)[:, np.newaxis]
test_label = test_df['polarity'].tolist()

# %%
# Build and fit
model = build_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# elmo_embedding_layer_1 (Elmo (None, 1024)              4
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 262,661
# Trainable params: 262,661
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_text, 
          train_label,
          validation_data=(test_text, test_label),
          epochs=20,
          batch_size=32)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/1
# 25000/25000 [==============================] - 966s 39ms/step - loss: 0.4470 - acc: 0.7879 - val_loss: 0.4513 - val_acc: 0.7866

# %%
model.save('ElmoModel.h5')
pre_save_preds = model.predict(test_text[0:100]) # predictions before we clear and reload model

# Clear and load model
model = None
model = build_model()
model.load_weights('ElmoModel.h5')

post_save_preds = model.predict(test_text[0:100]) # predictions after we clear and reload model
all(pre_save_preds == post_save_preds) # Are they the same?
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# elmo_embedding_layer_2 (Elmo (None, 1024)              4
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 262,661
# Trainable params: 262,661
# Non-trainable params: 0
# _________________________________________________________________
# True

# %%
elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)

# %%
embeddings = elmo(["the cat is on the mat", "dogs are in the fog"],signature="default",as_dict=True)["elmo"]

# %%
print(embeddings)
# Out:
# Tensor("module_apply_default/aggregation/mul_3:0", shape=(2, 6, 1024), dtype=float32)
